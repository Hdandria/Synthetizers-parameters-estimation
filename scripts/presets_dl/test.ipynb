# %%
from mido import Message
from pedalboard import Pedalboard, Reverb, load_plugin
from pedalboard.io import AudioFile

# %%
# Open Vital plugin
vital = load_plugin("/home/benjamin/Documents/work/Synthetizers-parameters-estimation/plugins/Vital.vst3")
print(vital.parameters.keys())
# Out:
# dict_keys(['beats_per_minute', 'chorus_filter_cutoff', 'chorus_delay_1', 'chorus_delay_2', 'chorus_mix', 'chorus_feedback', 'chorus_frequency', 'chorus_mod_depth', 'chorus_switch', 'chorus_sync', 'chorus_tempo', 'compressor_attack', 'compressor_band_gain', 'band_lower_ratio', 'band_lower_threshold', 'band_upper_ratio', 'band_upper_threshold', 'compressor_enabled_bands', 'compressor_high_gain', 'high_lower_ratio', 'high_lower_threshold', 'high_upper_ratio', 'high_upper_threshold', 'compressor_low_gain', 'low_lower_ratio', 'low_lower_threshold', 'low_upper_ratio', 'low_upper_threshold', 'compressor_switch', 'compressor_release', 'delay_mix', 'delay_feedback', 'delay_filter_cutoff', 'delay_filter_spread', 'delay_frequency', 'delay_switch', 'delay_style', 'delay_sync', 'delay_tempo', 'distortion_drive', 'distortion_filter_blend', 'distortion_filter_cutoff', 'distortion_filter_order', 'distortion_filter_resonance', 'distortion_mix', 'distortion_switch', 'distortion_type', 'effect_chain_order', 'envelope_1_attack', 'envelope_1_attack_power', 'envelope_1_decay', 'envelope_1_decay_power', 'envelope_1_release', 'envelope_1_release_power', 'envelope_1_sustain', 'envelope_2_attack', 'envelope_2_attack_power', 'envelope_2_decay', 'envelope_2_decay_power', 'envelope_2_release', 'envelope_2_release_power', 'envelope_2_sustain', 'envelope_3_attack', 'envelope_3_attack_power', 'envelope_3_decay', 'envelope_3_decay_power', 'envelope_3_release', 'envelope_3_release_power', 'envelope_3_sustain', 'envelope_4_attack', 'envelope_4_attack_power', 'envelope_4_decay', 'envelope_4_decay_power', 'envelope_4_release', 'envelope_4_release_power', 'envelope_4_sustain', 'envelope_5_attack', 'envelope_5_attack_power', 'envelope_5_decay', 'envelope_5_decay_power', 'envelope_5_release', 'envelope_5_release_power', 'envelope_5_sustain', 'envelope_6_attack', 'envelope_6_attack_power', 'envelope_6_decay', 'envelope_6_decay_power', 'envelope_6_release', 'envelope_6_release_power', 'envelope_6_sustain', 'eq_band_cutoff', 'eq_band_gain', 'eq_band_resonance', 'eq_high_cutoff', 'eq_high_gain', 'eq_high_mode', 'eq_high_resonance', 'eq_low_cutoff', 'eq_low_gain', 'eq_low_mode', 'eq_low_resonance', 'eq_switch', 'filter_1_blend', 'filter_1_comb_blend_offset', 'filter_1_cutoff', 'filter_1_drive', 'filter_1_filter_input', 'filter_1_formant_resonance', 'filter_1_formant_transpose', 'filter_1_formant_x', 'filter_1_formant_y', 'filter_1_key_track', 'filter_1_mix', 'filter_1_model', 'filter_1_switch', 'filter_1_resonance', 'filter_1_style', 'filter_2_blend', 'filter_2_comb_blend_offset', 'filter_2_cutoff', 'filter_2_drive', 'filter_2_filter_input', 'filter_2_formant_resonance', 'filter_2_formant_transpose', 'filter_2_formant_x', 'filter_2_formant_y', 'filter_2_key_track', 'filter_2_mix', 'filter_2_model', 'filter_2_switch', 'filter_2_resonance', 'filter_2_style', 'filter_fx_blend', 'filter_fx_comb_blend_offset', 'filter_fx_cutoff', 'filter_fx_drive', 'filter_fx_formant_resonance', 'filter_fx_formant_transpose', 'filter_fx_formant_x', 'filter_fx_formant_y', 'filter_fx_key_track', 'filter_fx_mix', 'filter_fx_model', 'filter_fx_switch', 'filter_fx_resonance', 'filter_fx_style', 'flanger_mix', 'flanger_feedback', 'flanger_frequency', 'flanger_mod_depth', 'flanger_switch', 'flanger_phase_offset', 'flanger_sync', 'flanger_tempo', 'legato', 'lfo_1_delay', 'lfo_1_fade_in', 'lfo_1_frequency', 'lfo_1_phase', 'lfo_1_sync', 'lfo_1_sync_type', 'lfo_1_tempo', 'lfo_2_delay', 'lfo_2_fade_in', 'lfo_2_frequency', 'lfo_2_phase', 'lfo_2_sync', 'lfo_2_sync_type', 'lfo_2_tempo', 'lfo_3_delay', 'lfo_3_fade_in', 'lfo_3_frequency', 'lfo_3_phase', 'lfo_3_sync', 'lfo_3_sync_type', 'lfo_3_tempo', 'lfo_4_delay', 'lfo_4_fade_in', 'lfo_4_frequency', 'lfo_4_phase', 'lfo_4_sync', 'lfo_4_sync_type', 'lfo_4_tempo', 'lfo_5_delay', 'lfo_5_fade_in', 'lfo_5_frequency', 'lfo_5_phase', 'lfo_5_sync', 'lfo_5_sync_type', 'lfo_5_tempo', 'lfo_6_delay', 'lfo_6_fade_in', 'lfo_6_frequency', 'lfo_6_phase', 'lfo_6_sync', 'lfo_6 ...

# %%
# Play a note: C4 (MIDI note 60) with velocity 0.8
sample_rate = 44100
audio = vital(
  [Message("note_on", note=60), Message("note_off", note=60, time=5)],
  duration=5, # seconds
  sample_rate=sample_rate,
)

from IPython.display import Audio

Audio(audio, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json

file = 'preset.vital'
with open(file, '+r') as f:
    preset_data = json.load(f)

# %%
print(preset_data.keys())
# Out:
# dict_keys(['author', 'comments', 'macro1', 'macro2', 'macro3', 'macro4', 'preset_name', 'preset_style', 'settings', 'synth_version'])

# %%
print(preset_data['settings'].keys())
# Out:
# dict_keys(['beats_per_minute', 'bypass', 'chorus_cutoff', 'chorus_delay_1', 'chorus_delay_2', 'chorus_dry_wet', 'chorus_feedback', 'chorus_frequency', 'chorus_mod_depth', 'chorus_on', 'chorus_spread', 'chorus_sync', 'chorus_tempo', 'chorus_voices', 'compressor_attack', 'compressor_band_gain', 'compressor_band_lower_ratio', 'compressor_band_lower_threshold', 'compressor_band_upper_ratio', 'compressor_band_upper_threshold', 'compressor_enabled_bands', 'compressor_high_gain', 'compressor_high_lower_ratio', 'compressor_high_lower_threshold', 'compressor_high_upper_ratio', 'compressor_high_upper_threshold', 'compressor_low_gain', 'compressor_low_lower_ratio', 'compressor_low_lower_threshold', 'compressor_low_upper_ratio', 'compressor_low_upper_threshold', 'compressor_mix', 'compressor_on', 'compressor_release', 'delay_aux_frequency', 'delay_aux_sync', 'delay_aux_tempo', 'delay_dry_wet', 'delay_feedback', 'delay_filter_cutoff', 'delay_filter_spread', 'delay_frequency', 'delay_on', 'delay_style', 'delay_sync', 'delay_tempo', 'distortion_drive', 'distortion_filter_blend', 'distortion_filter_cutoff', 'distortion_filter_order', 'distortion_filter_resonance', 'distortion_mix', 'distortion_on', 'distortion_type', 'effect_chain_order', 'env_1_attack', 'env_1_attack_power', 'env_1_decay', 'env_1_decay_power', 'env_1_delay', 'env_1_hold', 'env_1_release', 'env_1_release_power', 'env_1_sustain', 'env_2_attack', 'env_2_attack_power', 'env_2_decay', 'env_2_decay_power', 'env_2_delay', 'env_2_hold', 'env_2_release', 'env_2_release_power', 'env_2_sustain', 'env_3_attack', 'env_3_attack_power', 'env_3_decay', 'env_3_decay_power', 'env_3_delay', 'env_3_hold', 'env_3_release', 'env_3_release_power', 'env_3_sustain', 'env_4_attack', 'env_4_attack_power', 'env_4_decay', 'env_4_decay_power', 'env_4_delay', 'env_4_hold', 'env_4_release', 'env_4_release_power', 'env_4_sustain', 'env_5_attack', 'env_5_attack_power', 'env_5_decay', 'env_5_decay_power', 'env_5_delay', 'env_5_hold', 'env_5_release', 'env_5_release_power', 'env_5_sustain', 'env_6_attack', 'env_6_attack_power', 'env_6_decay', 'env_6_decay_power', 'env_6_delay', 'env_6_hold', 'env_6_release', 'env_6_release_power', 'env_6_sustain', 'eq_band_cutoff', 'eq_band_gain', 'eq_band_mode', 'eq_band_resonance', 'eq_high_cutoff', 'eq_high_gain', 'eq_high_mode', 'eq_high_resonance', 'eq_low_cutoff', 'eq_low_gain', 'eq_low_mode', 'eq_low_resonance', 'eq_on', 'filter_1_blend', 'filter_1_blend_transpose', 'filter_1_cutoff', 'filter_1_drive', 'filter_1_filter_input', 'filter_1_formant_resonance', 'filter_1_formant_spread', 'filter_1_formant_transpose', 'filter_1_formant_x', 'filter_1_formant_y', 'filter_1_keytrack', 'filter_1_mix', 'filter_1_model', 'filter_1_on', 'filter_1_resonance', 'filter_1_style', 'filter_2_blend', 'filter_2_blend_transpose', 'filter_2_cutoff', 'filter_2_drive', 'filter_2_filter_input', 'filter_2_formant_resonance', 'filter_2_formant_spread', 'filter_2_formant_transpose', 'filter_2_formant_x', 'filter_2_formant_y', 'filter_2_keytrack', 'filter_2_mix', 'filter_2_model', 'filter_2_on', 'filter_2_resonance', 'filter_2_style', 'filter_fx_blend', 'filter_fx_blend_transpose', 'filter_fx_cutoff', 'filter_fx_drive', 'filter_fx_formant_resonance', 'filter_fx_formant_spread', 'filter_fx_formant_transpose', 'filter_fx_formant_x', 'filter_fx_formant_y', 'filter_fx_keytrack', 'filter_fx_mix', 'filter_fx_model', 'filter_fx_on', 'filter_fx_resonance', 'filter_fx_style', 'flanger_center', 'flanger_dry_wet', 'flanger_feedback', 'flanger_frequency', 'flanger_mod_depth', 'flanger_on', 'flanger_phase_offset', 'flanger_sync', 'flanger_tempo', 'legato', 'lfo_1_delay_time', 'lfo_1_fade_time', 'lfo_1_frequency', 'lfo_1_keytrack_transpose', 'lfo_1_keytrack_tune', 'lfo_1_phase', 'lfo_1_smooth_mode', 'lfo_1_smooth_time', 'lfo_1_stereo', 'lfo_1_sync', 'lfo_1_sync_type', 'lfo_1_tempo', 'lfo_2_delay_time', 'lfo_2_fade_time', 'lfo_2_frequency', 'lfo_2_keytrack_transpose', 'lfo_2_keytrack_tune', 'lfo_2_phase', 'lfo_2_s ...

# %%
print(len(set(preset_data["settings"].keys())))
print(len(vital.parameters.keys()))
# Out:
# 776
# 775

# %%
# Number of keys in intersection
common_keys = set(preset_data["settings"].keys()).intersection(set(vital.parameters.keys()))
print(len(common_keys))
# Out:
# 519

# %%
# Show keys in preset but not in vital parameters
preset_only_keys = set(preset_data["settings"].keys()) - set(vital.parameters.keys())
print(preset_only_keys)

# Show keys in vital parameters but not in preset
vital_only_keys = set(vital.parameters.keys()) - set(preset_data["settings"].keys())
print(vital_only_keys)
# Out:
# {'osc_2_unison_voices', 'env_3_decay_power', 'env_1_attack_power', 'flanger_dry_wet', 'reverb_dry_wet', 'env_2_decay', 'osc_2_spectral_unison', 'filter_1_blend_transpose', 'osc_3_unison_voices', 'env_6_decay', 'osc_3_smooth_interpolation', 'random_4_keytrack_tune', 'chorus_spread', 'osc_2_distortion_phase', 'osc_1_tune', 'osc_3_distortion_amount', 'random_3_tempo', 'lfo_2_delay_time', 'random_1_stereo', 'env_5_attack', 'env_2_attack_power', 'compressor_low_upper_threshold', 'env_2_decay_power', 'osc_3_spectral_morph_spread', 'osc_3_spectral_morph_amount', 'lfo_7_keytrack_tune', 'lfo_3_delay_time', 'lfo_1_fade_time', 'env_3_delay', 'random_4_frequency', 'env_5_delay', 'random_2_sync_type', 'osc_3_on', 'osc_3_unison_detune', 'compressor_band_lower_ratio', 'chorus_on', 'osc_2_pan', 'env_2_sustain', 'lfo_4_keytrack_tune', 'random_4_sync_type', 'eq_on', 'env_5_release_power', 'env_6_release', 'osc_2_spectral_morph_type', 'lfo_5_keytrack_tune', 'osc_2_random_phase', 'osc_3_spectral_unison', 'random_3_keytrack_tune', 'random_3_sync_type', 'lfo_6_keytrack_transpose', 'osc_1_phase', 'compressor_high_lower_threshold', 'flanger_on', 'osc_1_stereo_spread', 'random_2_sync', 'random_3_frequency', 'filter_2_keytrack', 'osc_3_pan', 'osc_3_detune_range', 'osc_2_midi_track', 'compressor_band_upper_ratio', 'osc_2_stereo_spread', 'osc_1_unison_blend', 'macro_control_2', 'osc_1_unison_detune', 'env_3_sustain', 'osc_1_pan', 'lfo_2_fade_time', 'osc_1_transpose_quantize', 'phaser_dry_wet', 'compressor_band_upper_threshold', 'osc_3_view_2d', 'env_2_attack', 'lfo_7_fade_time', 'lfo_2_keytrack_transpose', 'env_5_decay_power', 'random_4_style', 'osc_3_level', 'osc_2_spectral_morph_amount', 'osc_1_detune_power', 'env_1_release', 'env_2_hold', 'lfo_8_keytrack_tune', 'osc_2_unison_blend', 'env_1_hold', 'lfo_3_keytrack_tune', 'random_3_style', 'lfo_8_delay_time', 'macro_control_4', 'osc_2_distortion_amount', 'osc_2_smooth_interpolation', 'env_1_delay', 'random_4_tempo', 'osc_3_stereo_spread', 'lfo_5_delay_time', 'osc_1_spectral_morph_spread', 'env_6_release_power', 'osc_2_spectral_morph_spread', 'delay_dry_wet', 'sample_on', 'osc_2_transpose_quantize', 'osc_3_random_phase', 'random_1_keytrack_tune', 'osc_2_frame_spread', 'compressor_high_upper_ratio', 'osc_1_random_phase', 'random_4_stereo', 'osc_3_phase', 'env_4_attack', 'osc_2_detune_range', 'random_1_frequency', 'env_1_decay', 'lfo_5_keytrack_transpose', 'osc_1_spectral_morph_type', 'osc_1_view_2d', 'wavetables', 'compressor_on', 'osc_2_phase', 'lfo_1_keytrack_transpose', 'osc_3_spectral_morph_type', 'filter_2_blend_transpose', 'lfo_4_delay_time', 'lfo_1_keytrack_tune', 'env_2_release', 'env_4_release_power', 'random_3_stereo', 'lfo_8_fade_time', 'osc_1_detune_range', 'delay_aux_tempo', 'osc_1_frame_spread', 'reverb_high_shelf_gain', 'env_6_attack', 'env_1_decay_power', 'compressor_high_lower_ratio', 'osc_1_transpose', 'osc_2_detune_power', 'lfo_4_keytrack_transpose', 'env_4_hold', 'env_5_attack_power', 'random_1_style', 'osc_1_spectral_unison', 'env_1_attack', 'osc_1_unison_voices', 'lfo_7_keytrack_transpose', 'random_2_tempo', 'env_4_delay', 'delay_aux_frequency', 'compressor_band_lower_threshold', 'osc_3_midi_track', 'env_6_decay_power', 'delay_on', 'compressor_low_upper_ratio', 'env_5_hold', 'osc_2_view_2d', 'env_6_hold', 'random_2_keytrack_transpose', 'random_1_sync_type', 'compressor_low_lower_threshold', 'osc_2_unison_detune', 'osc_3_tune', 'random_2_keytrack_tune', 'reverb_low_shelf_gain', 'chorus_cutoff', 'env_4_release', 'osc_1_distortion_amount', 'sample', 'env_3_attack_power', 'random_4_keytrack_transpose', 'osc_3_wave_frame', 'osc_3_unison_blend', 'osc_2_transpose', 'osc_3_frame_spread', 'osc_1_distortion_phase', 'osc_1_on', 'osc_3_stack_style', 'osc_2_destination', 'osc_2_stack_style', 'lfo_4_fade_time', 'osc_1_midi_track', 'filter_1_on', 'filter_fx_blend_transpose', 'compressor_low_lower_ratio', 'lfo_6_fade_time', 'env_6_sustain', 'filter_fx_keytrack', 'osc_3_transpose_quantize', 'env_3_rel ...
# {'envelope_1_decay', 'oscillator_2_distortion_type', 'oscillator_1_phase_randomization', 'envelope_6_delay', 'envelope_5_sustain', 'lfo_3_transpose', 'low_upper_threshold', 'random_lfo_1_style', 'lfo_1_fade_in', 'random_lfo_3_transpose', 'oscillator_2_destination', 'envelope_6_release', 'envelope_4_release_power', 'reverb_low_gain', 'reverb_low_cutoff', 'envelope_3_hold', 'reverb_high_gain', 'lfo_7_fade_in', 'delay_mix', 'random_lfo_4_sync', 'oscillator_2_frequency_morph_spread', 'macro_4', 'lfo_6_tune', 'oscillator_1_switch', 'envelope_4_release', 'random_lfo_1_sync_type', 'delay_frequency_2', 'envelope_3_attack_power', 'filter_2_switch', 'lfo_4_fade_in', 'oscillator_2_view_2d', 'envelope_6_decay', 'envelope_3_delay', 'oscillator_3_transpose', 'oscillator_2_unison_detune', 'random_lfo_2_transpose', 'oscillator_3_midi_track', 'oscillator_1_view_2d', 'oscillator_2_pan', 'oscillator_3_level', 'envelope_1_release_power', 'lfo_8_transpose', 'chorus_mix', 'lfo_8_fade_in', 'envelope_6_decay_power', 'oscillator_2_distortion_phase', 'lfo_5_fade_in', 'lfo_5_tune', 'random_lfo_4_tempo', 'oscillator_3_transpose_quantize', 'oscillator_2_wave_frame', 'oscillator_1_frequency_morph_type', 'lfo_7_tune', 'phaser_switch', 'envelope_6_hold', 'oscillator_1_phase', 'delay_tempo_2', 'oscillator_1_distortion_phase', 'envelope_2_decay_power', 'random_lfo_3_style', 'random_lfo_4_tune', 'random_lfo_2_sync', 'random_lfo_1_stereo', 'oscillator_3_distortion_amount', 'filter_fx_switch', 'lfo_7_delay', 'envelope_5_attack', 'chorus_filter_cutoff', 'oscillator_3_phase_randomization', 'oscillator_2_midi_track', 'random_lfo_2_style', 'random_lfo_2_sync_type', 'envelope_3_attack', 'chorus_filter_spread', 'oscillator_2_transpose', 'random_lfo_2_tempo', 'oscillator_3_tune', 'random_lfo_4_transpose', 'envelope_1_delay', 'lfo_8_delay', 'macro_2', 'envelope_2_delay', 'distortion_switch', 'oscillator_3_pan', 'envelope_1_attack', 'random_lfo_3_stereo', 'oscillator_1_distortion_type', 'filter_1_comb_blend_offset', 'oscillator_1_detune_range', 'high_lower_ratio', 'macro_3', 'lfo_3_delay', 'high_upper_ratio', 'low_lower_ratio', 'random_lfo_1_transpose', 'envelope_6_release_power', 'oscillator_3_distortion_type', 'random_lfo_4_stereo', 'lfo_2_tune', 'oscillator_1_unison_detune', 'random_lfo_2_tune', 'oscillator_3_phase', 'oscillator_2_distortion_amount', 'oscillator_3_unison_frame_spread', 'oscillator_1_frequency_morph_spread', 'low_upper_ratio', 'envelope_5_release', 'high_lower_threshold', 'flanger_mix', 'oscillator_3_switch', 'oscillator_2_frequency_morph_amount', 'random_lfo_4_style', 'random_lfo_3_tune', 'lfo_4_tune', 'oscillator_1_midi_track', 'macro_1', 'low_lower_threshold', 'oscillator_2_frequency_morph_phase', 'compressor_switch', 'random_lfo_1_frequency', 'oscillator_1_unison_frame_spread', 'lfo_5_delay', 'filter_fx_comb_blend_offset', 'band_lower_threshold', 'oscillator_3_unison_voices', 'envelope_4_sustain', 'random_lfo_4_frequency', 'oscillator_3_unison_detune', 'oscillator_1_spectral_unison', 'lfo_6_fade_in', 'envelope_2_attack_power', 'oscillator_2_stereo_spread', 'envelope_2_sustain', 'oscillator_3_destination', 'lfo_2_transpose', 'envelope_4_decay_power', 'sample_switch', 'envelope_5_decay', 'oscillator_3_wave_frame', 'reverb_high_cutoff', 'oscillator_3_distortion_spread', 'band_upper_threshold', 'oscillator_2_phase_randomization', 'filter_fx_key_track', 'envelope_5_release_power', 'oscillator_3_frequency_morph_phase', 'lfo_1_tune', 'oscillator_2_frequency_morph_type', 'envelope_1_decay_power', 'oscillator_1_stereo_spread', 'envelope_6_attack', 'oscillator_2_detune_range', 'lfo_1_transpose', 'envelope_1_release', 'delay_switch', 'random_lfo_2_frequency', 'envelope_4_delay', 'oscillator_1_transpose', 'envelope_5_delay', 'reverb_mix', 'filter_2_key_track', 'envelope_4_hold', 'oscillator_2_unison_voices', 'oscillator_3_blend', 'oscillator_1_transpose_quantize', 'oscillator_2_transpose_quantize', 'oscillator_3_stack_style', 'filter_2_comb_blend_offset', 'rand ...

# %%
CORE_COMPONENT_MAP = {
    # Component Mapping (Prefixes)
    "osc": "oscillator",
    "env": "envelope",
    "random": "random_lfo",

    # Macro Control Mapping
    "macro_control": "macro",

    # Effect Mapping
    "reverb": "reverb",
    "chorus": "chorus",
    "phaser": "phaser",
    "flanger": "flanger",
    "eq": "eq",
    "delay": "delay",
    "compressor": "compressor", # Stays 'compressor' in both, though Set 2 uses specific band terms

    # Other Core Modules
    "sample": "sample",
    "wavetables": "wavetables",
    "lfos": "lfos",
    "modulations": "modulations"
}

COMMON_SUFFIX_MAP = {
    # On/Off
    "_on": "_switch",

    # Envelope Parameter Mapping
    "_attack": "_attack",
    "_decay": "_decay",
    "_sustain": "_sustain",
    "_release": "_release",
    "_hold": "_hold",

    # LFO Keytracking
    "_keytrack_tune": "_tune",
    "_keytrack_transpose": "_transpose",
    "_fade_time": "_fade_in",

    # Oscillator Specific
    "_spectral_morph": "_frequency_morph",
    "_random_phase": "_phase_randomization",
    "_frame_spread": "_frame_spread", # Note: Set 2 often uses "unison_frame_spread" for this context

    # Effect Mix
    "_dry_wet": "_mix",

    # Filter/Effect Keytracking
    "_keytrack": "_key_track",
}

preset_new_settings = {}
for key, value in preset_data["settings"].items():
    new_key = key
    for prefix, mapped_prefix in CORE_COMPONENT_MAP.items():
        if key.startswith(prefix):
            new_key = key.replace(prefix, mapped_prefix, 1)
            break
    for suffix, mapped_suffix in COMMON_SUFFIX_MAP.items():
        if new_key.endswith(suffix):
            new_key = new_key[:-len(suffix)] + mapped_suffix
            break
    preset_new_settings[new_key] = value

# Print common length after remapping
common_keys_remapped = set(preset_new_settings.keys()).intersection(set(vital.parameters.keys()))
print(len(common_keys_remapped))

# Show keys in preset but not in vital parameters after remapping
preset_only_keys_remapped = set(preset_new_settings.keys()) - set(vital.parameters.keys())
print(preset_only_keys_remapped)

# Show keys in vital parameters but not in preset after remapping
vital_only_keys_remapped = set(vital.parameters.keys()) - set(preset_new_settings.keys())
print(vital_only_keys_remapped)
# Out:
# 723
# {'lfos', 'compressor_band_upper_threshold', 'oscillator_1_spectral_morph_amount', 'delay_aux_frequency', 'compressor_band_lower_threshold', 'filter_1_blend_transpose', 'oscillator_1_unison_blend', 'oscillator_2_frame_spread', 'compressor_low_upper_ratio', 'chorus_spread', 'oscillator_3_spectral_morph_spread', 'oscillator_1_spectral_morph_type', 'lfo_8_delay_time', 'compressor_high_upper_threshold', 'lfo_2_delay_time', 'lfo_5_delay_time', 'sample_phase_randomization', 'compressor_low_lower_threshold', 'sample_key_track', 'compressor_low_upper_threshold', 'oscillator_3_unison_blend', 'reverb_low_shelf_gain', 'oscillator_1_spectral_morph_spread', 'chorus_cutoff', 'lfo_3_delay_time', 'delay_aux_sync', 'lfo_1_delay_time', 'compressor_high_upper_ratio', 'sample', 'compressor_band_lower_ratio', 'lfo_7_delay_time', 'oscillator_1_frame_spread', 'lfo_6_delay_time', 'wavetables', 'oscillator_3_frame_spread', 'oscillator_3_spectral_morph_type', 'oscillator_3_spectral_morph_amount', 'filter_2_blend_transpose', 'oscillator_2_spectral_morph_amount', 'lfo_4_delay_time', 'modulations', 'compressor_high_lower_threshold', 'reverb_low_shelf_cutoff', 'oscillator_2_spectral_morph_type', 'delay_aux_tempo', 'filter_fx_blend_transpose', 'compressor_low_lower_ratio', 'reverb_high_shelf_gain', 'compressor_high_lower_ratio', 'compressor_band_upper_ratio', 'oscillator_2_spectral_morph_spread', 'reverb_high_shelf_cutoff', 'oscillator_2_unison_blend'}
# {'oscillator_2_frequency_morph_amount', 'low_upper_threshold', 'low_lower_threshold', 'oscillator_2_frequency_morph_phase', 'oscillator_1_unison_frame_spread', 'lfo_7_delay', 'reverb_low_gain', 'filter_fx_comb_blend_offset', 'band_lower_threshold', 'lfo_5_delay', 'oscillator_3_frequency_morph_type', 'reverb_low_cutoff', 'reverb_high_gain', 'chorus_filter_cutoff', 'sample_random_phase', 'lfo_4_delay', 'lfo_1_delay', 'oscillator_2_frequency_morph_spread', 'chorus_filter_spread', 'oscillator_2_unison_frame_spread', 'reverb_high_cutoff', 'oscillator_1_frequency_morph_amount', 'band_upper_threshold', 'delay_frequency_2', 'lfo_8_delay', 'oscillator_3_frequency_morph_phase', 'oscillator_2_frequency_morph_type', 'oscillator_2_blend', 'filter_1_comb_blend_offset', 'high_lower_ratio', 'lfo_3_delay', 'high_upper_ratio', 'low_lower_ratio', 'oscillator_3_blend', 'oscillator_1_frequency_morph_phase', 'filter_2_comb_blend_offset', 'oscillator_3_unison_frame_spread', 'sample_keytrack', 'oscillator_1_frequency_morph_type', 'oscillator_3_frequency_morph_spread', 'delay_sync_2', 'oscillator_1_frequency_morph_spread', 'high_upper_threshold', 'low_upper_ratio', 'lfo_6_delay', 'high_lower_threshold', 'band_upper_ratio', 'lfo_2_delay', 'delay_tempo_2', 'band_lower_ratio', 'oscillator_1_blend', 'oscillator_3_frequency_morph_amount'}

# %%
# All types using getattr(vital,key).type
from collections import Counter

compteur = Counter()
for key in common_keys_remapped:
    compteur[getattr(vital,key).type] += 1
print(compteur)
# Out:
# Counter({<class 'float'>: 326, <class 'bool'>: 240, <class 'str'>: 157})

# %%
# All types using getattr(vital,key).type
from collections import Counter

compteur = Counter()
for key in common_keys_remapped:
    if getattr(vital,key).type == str:
        print(f"{key}, {getattr(vital,key)}, {preset_new_settings[key]}")
    if getattr(vital,key).type == bool:
        print(f"{key}, {getattr(vital,key)}, {preset_new_settings[key]}")
print(compteur)
# Out:
# modulation_55_bipolar, False, 0.0
# oscillator_2_distortion_type, None, 0.0
# modulation_4_bipolar, False, 0.0
# modulation_6_bipolar, False, 0.0
# envelope_6_release, 0.0899194 secs, 0.5475999712944031
# oscillator_2_destination, FILTER 2, 0.0
# delay_sync, Tempo, 1.0
# envelope_3_hold, 0 secs, 0.0
# modulation_38_bipolar, False, 0.0
# modulation_11_bipolar, False, 0.0
# modulation_40_bypass, False, 0.0
# envelope_4_release, 0.0899194 secs, 0.5475999712944031
# lfo_1_frequency, 0.5 secs, 1.0
# reverb_delay, 0 secs, 0.0
# envelope_6_decay, 1 secs, 1.0
# oscillator_2_view_2d, On, 1.0
# filter_1_style, 12dB, 1.0
# portamento_time, 0.000976562 secs, -10.0
# lfo_5_fade_in, 0 secs, 0.0
# filter_1_cutoff, 0 semitones, 106.69924926757812
# random_lfo_4_tempo, 1/4, 8.0
# lfo_4_sync, Tempo, 1.0
# modulation_41_bipolar, False, 0.0
# lfo_5_smooth_mode, True, 1.0
# lfo_8_smooth_time, 0.00552427 secs, -7.5
# modulation_58_bypass, False, 0.0
# modulation_17_stereo, False, 0.0
# modulation_52_bipolar, False, 0.0
# modulation_28_bipolar, False, 0.0
# random_lfo_3_style, Perlin, 0.0
# modulation_28_bypass, False, 0.0
# modulation_46_stereo, False, 0.0
# random_lfo_2_sync, Tempo, 1.0
# modulation_4_bypass, False, 0.0
# modulation_25_bipolar, False, 0.0
# modulation_50_stereo, False, 0.0
# modulation_49_bipolar, False, 0.0
# random_lfo_2_style, Perlin, 2.0
# random_lfo_2_sync_type, False, 0.0
# modulation_36_bypass, False, 0.0
# envelope_1_delay, 0 secs, 0.0
# modulation_49_stereo, False, 0.0
# modulation_26_bypass, False, 0.0
# modulation_57_stereo, False, 0.0
# envelope_2_delay, 0 secs, 0.0
# envelope_1_attack, 0.000499534 secs, 0.1509743481874466
# modulation_10_stereo, False, 0.0
# modulation_21_bypass, False, 0.0
# modulation_56_bypass, False, 0.0
# random_lfo_4_stereo, False, 0.0
# modulation_45_bypass, False, 0.0
# lfo_8_frequency, 0.5 secs, 1.0
# modulation_54_bypass, False, 0.0
# modulation_55_bypass, False, 0.0
# modulation_8_bipolar, False, 0.0
# phaser_center, 80 semitones, 80.0
# mpe_enabled, False, 0.0
# modulation_26_bipolar, False, 0.0
# modulation_26_stereo, False, 0.0
# random_lfo_1_frequency, 0.5 secs, 1.0
# modulation_61_bipolar, False, 0.0
# oscillator_1_spectral_unison, True, 1.0
# modulation_29_bipolar, False, 0.0
# modulation_15_stereo, False, 0.0
# oscillator_3_destination, EFFECTS, 3.0
# modulation_31_bipolar, False, 0.0
# envelope_1_release, 0.0899194 secs, 0.7910539507865906
# modulation_51_bipolar, False, 0.0
# portamento_scale, False, 0.0
# modulation_30_stereo, False, 0.0
# compressor_enabled_bands, Multiband, 3.0
# eq_high_mode, Shelf, 1.0
# oscillator_2_unison_voices, 1v, 9.0
# modulation_63_bipolar, False, 0.0
# pitch_bend_range, 2 semitones, 2.0
# random_lfo_1_sync, Tempo, 1.0
# modulation_42_bipolar, False, 0.0
# envelope_4_attack, 0.000499534 secs, 0.14949999749660492
# modulation_5_stereo, False, 0.0
# modulation_24_stereo, False, 0.0
# modulation_49_bypass, False, 0.0
# modulation_12_bipolar, False, 0.0
# modulation_28_stereo, False, 0.0
# modulation_11_bypass, False, 0.0
# modulation_2_bypass, False, 0.0
# chorus_tempo, 4/1, 4.0
# modulation_48_stereo, False, 0.0
# modulation_18_bypass, False, 0.0
# modulation_16_stereo, False, 0.0
# modulation_58_stereo, False, 0.0
# modulation_41_bypass, False, 0.0
# random_lfo_3_sync, Tempo, 1.0
# lfo_8_sync_type, Trigger, 0.0
# phaser_tempo, 8/1, 3.0
# modulation_47_bipolar, False, 0.0
# oscillator_3_view_2d, On, 1.0
# modulation_64_bipolar, False, 0.0
# modulation_21_stereo, False, 0.0
# oscillator_1_unison_voices, 1v, 1.0
# phaser_frequency, 8 s, -3.0
# lfo_4_sync_type, Trigger, 0.0
# modulation_27_bipolar, False, 0.0
# modulation_34_bipolar, False, 0.0
# modulation_60_stereo, False, 0.0
# envelope_1_decay, 1 secs, 0.7813494205474854
# lfo_7_sync_type, Trigger, 0.0
# envelope_6_delay, 0 secs, 0.0
# lfo_3_smooth_time, 0.00552427 secs, -7.5
# modulation_5_bipolar, False, 0.0
# lfo_2_sync, Tempo, 1.0
# modulation_42_bypass, False, 0.0
# lfo_2_smooth_mode, True, 1.0
# modulation_16_bipolar, False, 0.0
# modulation_22_stereo, False, 0.0
# lfo_7_fade_in, 0 secs, 0.0
# modulation_53_bipolar, False, 0.0
# lfo_6_smooth_mode, True, 1.0
# random_lfo_1_sync_type, False, 0.0
# filter_2_switch, False, 0.0
# lfo_4_fade_in, 0 secs, 0.0
# modulation_45_bipolar, False, 0.0
# oscillator_1_view_2d, On, 1.0
# modulation_59_stereo, False, 0.0
# modulation_33_bipolar, False, 0.0
# modulation_9_bipolar, False, 0.0
# modulation_64_stereo, False, 0.0
# modulation_14_stereo, False, 0.0
# modulation_24_bipolar, False, 0.0
# eq_band_mode, Shelf, 0.0
# filter_fx_switch, False, 0.0
# modulation_4_stereo, False, 0.0
# modulation_63_bypass, False, 0.0
# filter_fx_cutoff, 0 semitones, 60.0
# modulation_32_bypass, False, 0.0
# modulation_14_bypass, False, 0.0
# chorus_frequency, 8 s, -3.0
# modulation_6_bypass, False, 0.0
# modulation_47_bypass, False, 0.0
# modulation_16_bypass, False, 0.0
# distortion_switch, False, 1.0
# modulation_30_bipolar, False, 0.0
# random_lfo_3_stereo, False, 0.0
# filter_1_filter_input, False, 0.0
# oscillator_3_distortion_type, None, 0.0
# eq_low_cutoff, 40 semitones, 47.11111068725586
# envelope_5_release, 0.0899194 secs, 0.5475999712944031
# lfo_5_tempo, 1/2, 7.0
# modulation_17_bypass, False, 0.0
# oscillator_3_switch, False, 0.0
# filter_2_model, Analog, 0.0
# lfo_2_frequency, 0.5 secs, 1.0
# modulation_35_stereo, False, 0.0
# modulation_62_bypass, False, 0.0
# modulation_40_stereo, False, 0.0
# modulation_59_bypass, False, 0.0
# flanger_frequency, 0.25 s, 2.0
# modulation_56_stereo, False, 0.0
# envelope_6_attack, 0.000499534 secs, 0.14949999749660492
# lfo_1_sync_type, Trigger, 1.0
# delay_switch, False, 0.0
# random_lfo_2_frequency, 0.5 secs, 1.0
# eq_low_mode, Shelf, 1.0
# envelope_4_delay, 0 secs, 0.0
# modulation_53_stereo, False, 0.0
# modulation_44_bypass, False, 0.0
# modulation_19_bypass, False, 0.0
# modulation_57_bypass, False, 0.0
# modulation_47_stereo, False, 0.0
# envelope_5_hold, 0 secs, 0.0
# modulation_59_bipolar, False, 0.0
# sample_loop, True, 0.0
# modulation_13_bipolar, False, 0.0
# random_lfo_3_frequency, 0.5 secs, 1.0
# filter_fx_model, Analog, 0.0
# modulation_3_bipolar, False, 0.0
# lfo_3_fade_in, 0 secs, 0.0
# filter_2_cutoff, 0 semitones, 60.0
# modulation_52_stereo, False, 0.0
# lfo_2_fade_in, 0 secs, 0.0
# distortion_type, Soft Clip, 4.0
# oscillator_2_stack_style, Unison, 0.0
# envelope_1_hold, 0 secs, 0.3662789762020111
# lfo_3_tempo, 1/2, 7.0
# chorus_switch, False, 1.0
# lfo_7_smooth_mode, True, 1.0
# modulation_52_bypass, False, 0.0
# envelope_2_decay, 1 secs, 1.0
# modulation_7_bipolar, False, 0.0
# envelope_4_decay, 1 secs, 1.0
# modulation_54_bipolar, False, 0.0
# modulation_12_stereo, False, 0.0
# modulation_18_bipolar, False, 0.0
# flanger_sync, Tempo, 1.0
# portamento_force, False, 0.0
# lfo_1_smooth_time, 0.00552427 secs, -7.5
# modulation_57_bipolar, False, 0.0
# modulation_37_stereo, False, 0.0
# voice_override, Kill, 0.0
# oscillator_3_spectral_unison, True, 1.0
# oscillator_2_switch, False, 1.0
# modulation_48_bypass, False, 0.0
# delay_frequency, 0.25 secs, 2.0
# modulation_56_bipolar, False, 0.0
# modulation_25_bypass, False, 0.0
# modulation_63_stereo, False, 0.0
# modulation_31_stereo, False, 0.0
# random_lfo_1_style, Perlin, 0.0
# lfo_1_fade_in, 0 secs, 0.0
# lfo_7_frequency, 0.5 secs, 1.0
# modulation_62_stereo, False, 0.0
# random_lfo_4_sync, Tempo, 1.0
# flanger_tempo, 4/1, 4.0
# modulation_33_bypass, False, 0.0
# envelope_3_delay, 0 secs, 0.0
# flanger_center, 64 semitones, 64.0
# view_spectrogram, Off, 0.0
# oscillator_3_midi_track, True, 1.0
# modulation_24_bypass, False, 0.0
# modulation_34_stereo, False, 0.0
# modulation_55_stereo, False, 0.0
# modulation_7_bypass, False, 0.0
# eq_band_cutoff, 80 semitones, 80.0
# modulation_1_stereo, False, 0.0
# phaser_switch, False, 0.0
# envelope_6_hold, 0 secs, 0.0
# modulation_27_bypass, False, 0.0
# delay_style, Mono, 0.0
# modulation_15_bipolar, False, 0.0
# modulation_43_bypass, False, 0.0
# modulation_20_bypass, False, 0.0
# envelope_5_attack, 0.000499534 secs, 0.14949999749660492
# legato, False, 0.0
# modulation_51_bypass, False, 0.0
# modulation_11_stereo, False, 0.0
# modulation_32_bipolar, False, 0.0
# oscillator_2_midi_track, True, 1.0
# envelope_3_attack, 0.000499534 secs, 0.14949999749660492
# modulation_43_stereo, False, 0.0
# modulation_22_bipolar, False, 0.0
# random_lfo_2_tempo, 1/4, 6.0
# voice_priority, Round Robin, 4.0
# oscillator_1_distortion_type, None, 0.0
# modulation_46_bypass, False, 0.0
# lfo_3_smooth_mode, True, 1.0
# modulation_6_stereo, False, 0.0
# modulation_46_bipolar, False, 0.0
# lfo_4_frequency, 0.5 secs, 1.0
# modulation_23_bipolar, False, 0.0
# sample_bounce, False, 0.0
# modulation_8_stereo, False, 0.0
# modulation_34_bypass, False, 0.0
# voice_tune, 0 c, 0.0
# random_lfo_4_style, Perlin, 0.0
# oscillator_1_midi_track, True, 1.0
# modulation_61_stereo, False, 0.0
# lfo_8_tempo, 1/2, 7.0
# compressor_switch, False, 1.0
# lfo_4_smooth_time, 0.00552427 secs, -7.5
# random_lfo_4_frequency, 0.5 secs, 1.0
# lfo_6_fade_in, 0 secs, 0.0
# modulation_30_bypass, False, 0.0
# lfo_6_smooth_time, 0.00552427 secs, -7.5
# filter_2_style, 12dB, 0.0
# sample_switch, False, 1.0
# modulation_61_bypass, False, 0.0
# envelope_5_decay, 1 secs, 1.0
# modulation_39_bypass, False, 0.0
# modulation_44_bipolar, False, 0.0
# modulation_35_bypass, False, 0.0
# modulation_42_stereo, False, 0.0
# lfo_6_frequency, 0.5 secs, 1.0
# modulation_7_stereo, False, 0.0
# envelope_4_hold, 0 secs, 0.0
# lfo_2_tempo, 1/2, 9.0
# envelope_3_release, 0.0899194 secs, 0.5475999712944031
# envelope_2_release, 0.0899194 secs, 0.5475999712944031
# modulation_9_stereo, False, 0.0
# lfo_8_sync, Tempo, 1.0
# envelope_3_decay, 1 secs, 1.0
# stereo_mode, SPREAD, 0.0
# modulation_3_bypass, False, 0.0
# modulation_36_stereo, False, 0.0
# modulation_17_bipolar, False, 0.0
# modulation_32_stereo, False, 0.0
# lfo_1_tempo, 1/2, 10.0
# oscillator_1_destination, FILTER 1, 0.0
# modulation_22_bypass, False, 0.0
# modulation_39_bipolar, False, 0.0
# random_lfo_2_stereo, False, 0.0
# oscillator_1_stack_style, Unison, 0.0
# modulation_2_stereo, False, 0.0
# lfo_8_smooth_mode, True, 1.0
# modulation_27_stereo, False, 0.0
# modulation_29_bypass, False, 0.0
# random_lfo_4_sync_type, False, 0.0
# reverb_switch, False, 1.0
# eq_high_cutoff, 100 semitones, 123.26066589355469
# lfo_5_sync_type, Trigger, 0.0
# modulation_58_bipolar, False, 0.0
# modulation_1_bipolar, False, 0.0
# phaser_mod_depth, 24 semitones, 24.0
# modulation_37_bipolar, False, 0.0
# oscillator_1_switch, True, 1.0
# lfo_5_frequency, 0.5 secs, 1.0
# modulation_50_bypass, False, 0.0
# modulation_23_bypass, False, 0.0
# modulation_50_bipolar, False, 0.0
# modulation_14_bipolar, False, 0.0
# modulation_43_bipolar, False, 0.0
# lfo_7_sync, Tempo, 1.0
# lfo_7_smooth_time, 0.00552427 secs, -7.5
# lfo_7_tempo, 1/2, 7.0
# lfo_8_fade_in, 0 secs, 0.0
# modulation_2_bipolar, False, 1.0
# modulation_21_bipolar, False, 0.0
# lfo_6_sync_type, Trigger, 0.0
# modulation_8_bypass, False, 0.0
# modulation_38_stereo, False, 0.0
# lfo_6_tempo, 1/2, 7.0
# modulation_35_bipolar, False, 0.0
# polyphony, 8 voices, 8.0
# random_lfo_1_stereo, False, 0.0
# filter_fx_style, 12dB, 0.0
# modulation_12_bypass, False, 0.0
# modulation_13_stereo, False, 0.0
# lfo_5_sync, Tempo, 1.0
# modulation_31_bypass, False, 0.0
# lfo_2_smooth_time, 0.00552427 secs, -10.0
# modulation_38_bypass, False, 0.0
# modulation_44_stereo, False, 0.0
# filter_1_model, Analog, 0.0
# lfo_2_sync_type, Trigger, 5.0
# modulation_40_bipolar, False, 0.0
# modulation_62_bipolar, False, 0.0
# modulation_15_bypass, False, 0.0
# reverb_decay_time, 1 secs, 2.640000104904175
# reverb_pre_low_cutoff, 0 semitones, 0.0
# modulation_48_bipolar, False, 0.0
# lfo_3_sync, Tempo, 1.0
# modulation_41_stereo, False, 0.0
# modulation_18_stereo, False, 0.0
# modulation_64_bypass, False, 0.0
# oscillator_3_unison_voices, 1v, 1.0
# modulation_37_bypass, False, 0.0
# distortion_filter_cutoff, 80 semitones, 101.12000274658203
# lfo_3_frequency, 0.5 secs, 1.0
# lfo_3_sync_type, Trigger, 3.0
# modulation_29_stereo, False, 0.0
# modulation_60_bipolar, False, 0.0
# modulation_23_stereo, False, 0.0
# envelope_5_delay, 0 secs, 0.0
# modulation_36_bipolar, False, 0.0
# modulation_54_stereo, False, 0.0
# delay_tempo, 1/8, 8.0
# oscillator_3_stack_style, Unison, 0.0
# envelope_2_hold, 0 secs, 0.0
# lfo_6_sync, Tempo, 1.0
# eq_switch, False, 1.0
# oscillator_3_smooth_interpolation, False, 0.0
# modulation_51_stereo, False, 0.0
# oscillator_2_spectral_unison, True, 1.0
# envelope_2_attack, 0.000499534 secs, 0.14949999749660492
# modulation_33_stereo, False, 0.0
# modulation_53_bypass, False, 0.0
# lfo_1_smooth_mode, True, 1.0
# modulation_20_stereo, False, 0.0
# modulation_60_bypass, False, 0.0
# modulation_1_bypass, False, 0.0
# sample_destination, EFFECTS, 3.0
# lfo_4_smooth_mode, True, 1.0
# random_lfo_1_tempo, 1/4, 10.0
# filter_2_filter_input, False, 0.0
# filter_1_switch, False, 1.0
# flanger_switch, False, 0.0
# modulation_25_stereo, False, 0.0
# lfo_1_sync, Tempo, 1.0
# modulation_10_bipolar, False, 0.0
# modulation_3_stereo, False, 0.0
# reverb_pre_high_cutoff, 110 semitones, 110.0
# oscillator_1_smooth_interpolation, False, 0.0
# modulation_9_bypass, False, 0.0
# modulation_5_bypass, False, 0.0
# modulation_19_stereo, False, 0.0
# modulation_20_bipolar, False, 0.0
# modulation_10_bypass, False, 0.0
# random_lfo_3_tempo, 1/4, 8.0
# lfo_5_smooth_time, 0.00552427 secs, -7.5
# lfo_4_tempo, 1/2, 7.0
# random_lfo_3_sync_type, False, 0.0
# phaser_sync, Tempo, 1.0
# oscillator_2_smooth_interpolation, False, 0.0
# chorus_sync, Tempo, 1.0
# modulation_19_bipolar, False, 0.0
# modulation_39_stereo, False, 0.0
# distortion_filter_order, None, 2.0
# modulation_13_bypass, False, 0.0
# modulation_45_stereo, False, 0.0
# Counter()

# %%
# Play with the plugin parameters
sound = vital(
  [Message("note_on", note=10), Message("note_off", note=10, time=5)],
  duration=5,
  sample_rate=sample_rate,
)
Audio(sound, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# For all of these keys in common_keys_remapped, set the vital parameter to the preset value
failed = 0
success = 0
skipped = 0

for key in common_keys_remapped:
    try:
        param_type = getattr(vital, key).type

        # Skip string parameters
        if param_type == str:
            skipped += 1
            continue

        # Convert value based on parameter type
        value = preset_new_settings[key]

        if param_type == bool:
            if isinstance(value, str):
                value = value.lower() in ['true', '1', '1.0', 'yes']
            else:
                value = bool(value)
        else:
            # Handle numeric types (float/int)
            value = float(value) if param_type == float else value

        # Set the parameter
        setattr(vital, key, value)
        success += 1

    except Exception as e:
        print(f"Failed to set {key}: {e}")
        failed += 1

print(f"Skipped: {skipped}, Failed: {failed}, Success: {success}")
# Out:
# Failed to set beats_per_minute: Value received for parameter 'beats_per_minute' (1.5000001192092896) is out of range [20.0None, 300.0None]
# Failed to set chorus_delay_2: Value received for parameter 'chorus_delay_2' (-7.0) is out of range [0.976562ms, 19.9999ms]
# Failed to set filter_fx_formant_resonance: Value received for parameter 'filter_fx_formant_resonance' (0.8500000238418579) is out of range [30.0%, 100.0%]
# Failed to set chorus_delay_1: Value received for parameter 'chorus_delay_1' (-9.0) is out of range [0.976562ms, 19.9999ms]
# Failed to set reverb_chorus_frequency: Value received for parameter 'reverb_chorus_frequency' (-2.0) is out of range [0.00390625Hz, 8.0Hz]
# Failed to set filter_2_formant_resonance: Value received for parameter 'filter_2_formant_resonance' (0.8500000238418579) is out of range [30.0%, 100.0%]
# Failed to set filter_1_formant_resonance: Value received for parameter 'filter_1_formant_resonance' (0.8500000238418579) is out of range [30.0%, 100.0%]
# Failed to set volume: Value received for parameter 'volume' (5473.04052734375) is out of range [-80.0dB, 6.02dB]
# Failed to set chorus_voices: Value received for parameter 'chorus_voices' (1.0) is out of range [4.0None, 16.0None]
# Skipped: 157, Failed: 9, Success: 557

# %%
# Play with the plugin parameters
sound = vital(
  [Message("note_on", note=10), Message("note_off", note=10, time=5)],
  duration=5,
  sample_rate=sample_rate,
)
Audio(sound, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json
import pickle

from pedalboard import load_plugin

# Load the plugin
vital = load_plugin("/home/benjamin/Documents/work/Synthetizers-parameters-estimation/plugins/Surge XTz.vst3")

# This will pause the script until you close the VST window
print("Opening plugin editor... Close the editor window to continue.")
vital.show_editor()

print("Reading parameters after manual edits...")

pickle.dump(vital.parameters)

print(f"Read parameters: {read_success} succeeded, {read_failure} failed/skipped.")

# Serialize successfully read parameters to JSON
if param_value_dict:
    with open("params.json", "w") as f:
        json.dump(param_value_dict, f, indent=2)
    print(f"Parameters serialized successfully to params.json ({len(param_value_dict)} parameters).")
else:
    print("No serializable parameters were read.")

# --- Test Reloading the Parameters ---
print("Reloading parameters from serialized values...")
set_success, set_failure = 0, 0
for parameter_name, serialized_value in param_value_dict.items():
    try:
        setattr(vital, parameter_name, serialized_value)
        set_success += 1
    except Exception as e:
        # This might fail if a parameter is read-only or expects a different type
        print(f"Failed to set {parameter_name}: {e}")
        set_failure += 1

print(f"Reloaded parameters: {set_success} succeeded, {set_failure} failed.")
# Out:
# Opening plugin editor... Close the editor window to continue.
# Reading parameters after manual edits...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 14
#      10 vital.show_editor()
#      12 print("Reading parameters after manual edits...")
# ---> 14 pickle.dump(vital.parameters)
#      16 print(f"Read parameters: {read_success} succeeded, {read_failure} failed/skipped.")
#      18 # Serialize successfully read parameters to JSON
#
# TypeError: dump() missing required argument 'file' (pos 2)

# %%
import json
import pickle

from pedalboard import load_plugin

# Load the plugin
vital = load_plugin("/home/benjamin/Documents/work/Synthetizers-parameters-estimation/plugins/Surge XT.vst3")

# This will pause the script until you close the VST window
print("Opening plugin editor... Close the editor window to continue.")
vital.show_editor()

print("Reading parameters after manual edits...")
# Out:
# Opening plugin editor... Close the editor window to continue.
# Reading parameters after manual edits...

# %%
pickle.dump(vital.parameters, open("vital_params.pkl", "wb"))
print("Parameters saved to vital_params.pkl")
# Out:
# {'m1': <pedalboard.AudioProcessorParameter name="M1: -" discrete raw_value=0 value=0.000000 range=(0.0, 0.0, ?)>, 'm2': <pedalboard.AudioProcessorParameter name="M2: -" discrete raw_value=0 value=0.000000 range=(0.0, 0.0, ?)>, 'm3': <pedalboard.AudioProcessorParameter name="M3: -" discrete raw_value=0 value=0.000000 range=(0.0, 0.0, ?)>, 'm4': <pedalboard.AudioProcessorParameter name="M4: -" discrete raw_value=0 value=0.000000 range=(0.0, 0.0, ?)>, 'm5': <pedalboard.AudioProcessorParameter name="M5: -" discrete raw_value=0 value=0.000000 range=(0.0, 0.0, ?)>, 'm6': <pedalboard.AudioProcessorParameter name="M6: -" discrete raw_value=0 value=0.000000 range=(0.0, 0.0, ?)>, 'm7': <pedalboard.AudioProcessorParameter name="M7: -" discrete raw_value=0 value=0.000000 range=(0.0, 0.0, ?)>, 'm8': <pedalboard.AudioProcessorParameter name="M8: -" discrete raw_value=0 value=0.000000 range=(0.0, 0.0, ?)>, 'send_fx_1_return': <pedalboard.AudioProcessorParameter name="Send FX 1 Return" discrete raw_value=1 value=0.00 dB range=(-inf, 0.0, ~inf)>, 'send_fx_2_return': <pedalboard.AudioProcessorParameter name="Send FX 2 Return" discrete raw_value=1 value=0.00 dB range=(-inf, 0.0, ~inf)>, 'send_fx_3_return': <pedalboard.AudioProcessorParameter name="Send FX 3 Return" discrete raw_value=1 value=0.00 dB range=(-inf, 0.0, ~inf)>, 'send_fx_4_return': <pedalboard.AudioProcessorParameter name="Send FX 4 Return" discrete raw_value=1 value=0.00 dB range=(-inf, 0.0, ~inf)>, 'global_volume': <pedalboard.AudioProcessorParameter name="Global Volume" discrete raw_value=0.957797 value=-2.03 dB range=(-48.0, 0.0, ~0.045)>, 'active_scene': <pedalboard.AudioProcessorParameter name="Active Scene" discrete raw_value=0.005 value=0 range=(0.0, 1.0, 1.0)>, 'scene_mode': <pedalboard.AudioProcessorParameter name="Scene Mode" discrete raw_value=0.005 value="Single" (4 valid string values)>, 'split_point': <pedalboard.AudioProcessorParameter name="Split Point" discrete raw_value=0.472717 value="C4" (128 valid string values)>, 'fx_disable': <pedalboard.AudioProcessorParameter name="FX Disable" discrete raw_value=0 value="-" (1 valid string value)>, 'polyphony_limit': <pedalboard.AudioProcessorParameter name="Polyphony Limit" discrete raw_value=0.228548 value=16 range=(2.0, 64.0, 1.0)>, 'fx_chain_bypass': <pedalboard.AudioProcessorParameter name="FX Chain Bypass" discrete raw_value=0.005 value="All FX" (4 valid string values)>, 'fx_a1_fx_type': <pedalboard.AudioProcessorParameter name="FX A1 FX Type" discrete raw_value=0.005 value="Off" (30 valid string values)>, 'fx_a1_param_1': <pedalboard.AudioProcessorParameter name="FX A1 Param 1" discrete raw_value=0 value=-48.00 dB range=(-48.0, 48.0, ~0.095)>, 'fx_a1_param_2': <pedalboard.AudioProcessorParameter name="FX A1 Param 2" discrete raw_value=0 value=13.75 Hz range=(13.75, 25087.71, ~32.68579842931937)>, 'fx_a1_param_3': <pedalboard.AudioProcessorParameter name="FX A1 Param 3" discrete raw_value=0 value="0.00 octaves" (501 valid string values)>, 'fx_a1_param_4': <pedalboard.AudioProcessorParameter name="FX A1 Param 4" discrete raw_value=0 value=-48.00 dB range=(-48.0, 48.0, ~0.095)>, 'fx_a1_param_5': <pedalboard.AudioProcessorParameter name="FX A1 Param 5" discrete raw_value=0 value=13.75 Hz range=(13.75, 25087.71, ~32.68579842931937)>, 'fx_a1_param_6': <pedalboard.AudioProcessorParameter name="FX A1 Param 6" discrete raw_value=0 value="0.00 octaves" (501 valid string values)>, 'fx_a1_param_7': <pedalboard.AudioProcessorParameter name="FX A1 Param 7" discrete raw_value=0 value=-48.00 dB range=(-48.0, 48.0, ~0.095)>, 'fx_a1_param_8': <pedalboard.AudioProcessorParameter name="FX A1 Param 8" discrete raw_value=0 value=13.75 Hz range=(13.75, 25087.71, ~32.68579842931937)>, 'fx_a1_param_9': <pedalboard.AudioProcessorParameter name="FX A1 Param 9" discrete raw_value=0 value="0.00 octaves" (501 valid string values)>, 'fx_a1_param_10': <pedalboard.AudioProcessorParameter name="FX A1 Param 10" discrete raw_value=0 value=-48.00 dB ran ...

# %%
# Play with the plugin parameters
sample_rate = 44100
sound = vital([Message("note_on", note=72), Message("note_off", note=72, time=2)],
        sample_rate=sample_rate,
        duration=2,
        num_channels=2
)
Audio(sound, rate=sample_rate)

sound2 = vital([Message("note_on", note=50), Message("note_off", note=50, time=2)],
        sample_rate=sample_rate,
        duration=2,
        num_channels=2
)
Audio(sound2, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Reload the plugin
vital_reset = load_plugin("/home/benjamin/Documents/work/Synthetizers-parameters-estimation/plugins/Surge XT.vst3")

# Load the parameters
vital_reset.parameters = pickle.load(open("vital_params.pkl", "rb"))

# Play with the reloaded plugin parameters
sample_rate = 44100
sound = vital_reset([Message("note_on", note=72), Message("note_off", note=72, time=2)],
        sample_rate=sample_rate,
        duration=2,
        num_channels=2
)
Audio(sound, rate=sample_rate)

sound2 = vital_reset([Message("note_on", note=50), Message("note_off", note=50, time=2)],
        sample_rate=sample_rate,
        duration=2,
        num_channels=2
)
Audio(sound2, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
